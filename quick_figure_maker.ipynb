# %%
import matplotlib.pyplot as plt
import torch
import numpy as np

from distmesh import *
from FEM_TPT import *
from maier_stein_vector_field import make_direction_field

import maierstein_euler_maruyama as mem
import maierstein_metadynamics_sampling as mms

import nn_solver_PINN_approach as ms

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./training_data/sample_path-num_pts-1000000-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-14-20.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Quasi-uniform simulation: 1e6 points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./training_data/sample_path-num_pts-1000000-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-14-20.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_4511/670846261.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./training_data/delta_rarified-num_pts-63173-delta-0.005-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-29-11-25.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Rarefied quasi-uniform sample: 63,173 points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./training_data/delta_rarified-num_pts-63173-delta-0.005-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-29-11-25.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/3605698976.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./guassian_deposits_metadynamics/sample_path-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-12-48.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Metadynamics simulation: 1e6 points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./guassian_deposits_metadynamics/sample_path-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-12-48.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_4511/1259037071.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./guassian_deposits_metadynamics/g_l-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-12-48.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Location of Guassian Deposits: 1000 deposits")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./guassian_deposits_metadynamics/g_l-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-12-48.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/4219219683.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./training_data/fem_mesh_points_A_B_removed-True_4224totalpts.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("FEM inputs: 4224 points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./training_data/fem_mesh_points_A_B_removed-True_4224totalpts.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_4511/3661428986.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./training_data/uniformsample11250pts.pt")
# then we initialize ax and fig
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Uniform sample: 150 by 75 grid points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./training_data/uniformsample11250pts.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_4511/965533018.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# first we load the data we will plot: 
x1 = torch.load(f="./training_data/uniformAB_REMOVEDsample9878pts.pt")
# then we initialize ax and fig
fig, ax = plt.subplots() 
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')
# then we scatter plot:
ax.scatter(x1[:,0].detach().numpy(), x1[:,1].detach().numpy(), s=1)
# then we add titles:
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Uniform sample: 9,878 points")
# then we show the plot:
fig.show()
# then we save the plot: 
fig.savefig("./training_data/uniformAB_REMOVEDsample9878pts.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/2448460717.py:27: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,30,30,1])
model.load_state_dict(torch.load("./model_weights/pinn_NumOfTrPts-54636_LayerArray-[2, 30, 30, 1]_alpha-10.0_epochs-100_DATE-2022-8-4-11-49"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/3325382178.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,30,30,1])
model.load_state_dict(torch.load("./model_weights/pinn_NumOfTrPts-17255_LayerArray-[2, 30, 30, 1]_alpha-15.0_epochs-100_DATE-2022-8-4-10-53"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/2895208151.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,20,20,1])
model.load_state_dict(torch.load("./model_weights/pinn_NumOfTrPts-17255_LayerArray-[2, 20, 20, 1]_alpha-10.0_epochs-100_DATE-2022-8-4-11-0"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots(figsize=(16,6))
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
fig.savefig("../final_presentation/worstapprox.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/998269630.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()
labels = ['','[20]', '[30]', '[20,20]', '[30,20]', '[30,30]', '']
x = np.arange(len(labels))
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_xlabel("Neural Net Architecture (hidden nodes per layer: [layer 1, layer 2])")
ax.set_yscale("log")
fig.show()
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_10750/1040321886.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots()
# then we add the direction field to the ax
make_direction_field(ax)
# then we put a circle around the regions A and B:
NA = 1000
NB = 1000
xa=-1
ya=0 
xb=1 
yb=0
ra = 0.3
rb = 0.3
ptsA = put_pts_on_circle(xa,ya,ra,NA) 
ptsB = put_pts_on_circle(xb,yb,rb,NB)  
plt.plot(ptsA[:,0],ptsA[:,1],linewidth = 2,c = 'y')
plt.plot(ptsB[:,0],ptsB[:,1],linewidth = 2,c = 'r')

# plot a trajectory: 
# g_l = torch.load("./guassian_deposits_metadynamics/g_l-bumps-1000-tau-1000-h_param-0.2-w_param-0.025-deltat-0.001-datetime-2022-7-28-12-48.pt")
# sp = mms.run_biased_sample_path(40000,g_l)
# color = mem.get_color(n_iterations=40000)
# plt.scatter(sp[:,0].detach(), sp[:,1].detach(), s=1, c=color)

# plot trajectory:
# sp = mem.get_sample_path(500000,np.array([[-1],[0]]))
# color = mem.get_color(n_iterations=500000)
# plt.scatter(sp[:,0], sp[:,1], s=1, c=color)

# ax.annotate("A",(0.95,0.5),c="orange")
# ax.annotate("B",(-1.05,0.5),c="orange")

fig.show()
fig.savefig("../symposium_presentation_reu/b(x).png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/3412595270.py:32: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,20,20,1])
model.load_state_dict(torch.load("./model_weights1/hyrbid_NumOfTrPts-63173_LayerArray-[2, 20, 20, 1]_epochs-100_DATE-2022-8-11-15-5"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/1232110986.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,20,20,1])
model.load_state_dict(torch.load("./model_weights1/hyrbid_NumOfTrPts-54636_LayerArray-[2, 20, 20, 1]_epochs-100_DATE-2022-8-11-15-3"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/717914341.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,20,20,1])
model.load_state_dict(torch.load("./model_weights1/pinn_NumOfTrPts-54636_LayerArray-[2, 20, 20, 1]_alpha-10.0_epochs-100_DATE-2022-8-11-14-43"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
q = q.detach().numpy()
q = q.squeeze()
q_FEM = np.loadtxt('MaierStein_q_FEM.csv', delimiter=',', dtype=float)
q_ab = np.absolute(q_FEM - q)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q_ab)
fig.colorbar(cb)
fig.show()
fig.savefig("../REU Final Report/images/badapprox1.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/3838560912.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,20,20,1])
model.load_state_dict(torch.load("./model_weights1/hyrbid_NumOfTrPts-17255_LayerArray-[2, 20, 20, 1]_epochs-100_DATE-2022-8-11-14-52"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
q = q.detach().numpy()
q = q.squeeze()
q_FEM = np.loadtxt('MaierStein_q_FEM.csv', delimiter=',', dtype=float)
q_ab = np.absolute(q_FEM - q)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q_ab)
fig.colorbar(cb)
fig.show()
fig.savefig("../REU Final Report/images/hybridapprox.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/1528738658.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,30,30,1])
model.load_state_dict(torch.load("./model_weights/pinn_NumOfTrPts-54636_LayerArray-[2, 30, 30, 1]_alpha-10.0_epochs-100_DATE-2022-8-4-11-49"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
q = q.detach().numpy()
q = q.squeeze()
q_FEM = np.loadtxt('MaierStein_q_FEM.csv', delimiter=',', dtype=float)
q_ab = np.absolute(q_FEM - q)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q_ab)
fig.colorbar(cb)
fig.show()
fig.savefig("../REU Final Report/images/pinnerror1.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/1301328358.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# check a model approximation 
model = ms.NeuralNetwork(layer_array=[2,30,30,1])
model.load_state_dict(torch.load("./model_weights/pinn_NumOfTrPts-54636_LayerArray-[2, 30, 30, 1]_alpha-10.0_epochs-100_DATE-2022-8-4-11-49"))
pts = np.loadtxt('MaierStein_pts.csv', delimiter=',', dtype=float)
# work around the error of inputting numpy data into torch nn
pts_torch = torch.tensor(pts).float()
q = model(pts_torch)
fig, ax = plt.subplots()
cb = ax.scatter(pts[:,0], pts[:,1], c=q.detach().numpy())
fig.colorbar(cb)
fig.show()
fig.savefig("../REU Final Report/images/pinnapprox1.png")
# Out:
# /var/folders/mh/gbj7v0tx7cn3t6x4ypc457mr0000gn/T/ipykernel_72666/1790232071.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
